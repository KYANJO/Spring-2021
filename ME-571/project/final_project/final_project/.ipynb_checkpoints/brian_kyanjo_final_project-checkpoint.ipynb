# %% [markdown]
# # Final Project
# ## Name: Brian KYANJO
# ### Class: ME 571
# #### Date: April, 21st 2021

# %%
# %matplotlib notebook
# %pylab
import pandas as pd
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Task1. 2)

# %%
#import task1 data
task1 = pd.read_csv('task_1.csv')

time = array(task1['time'])
N = array(task1['N'])

# %%
ep = 1e-5
Np = 100/(ep**2)
n = zeros(len(N)); n[0] = Np

# %%
time[7]
# Out:
# 15.730502

# %%
figure(1)
#plot(N7,t7,"o")
loglog(N,time,'-*')
#loglog(error,time,'-*')
vlines(N[7],0,time[7],'r','--')
hlines(time[7],0,N[7],'r','--')

title('Time against N')
xlabel('N')
#xlim(0e3,1e13)
ylabel('Time')
grid()
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# # strong scaling

# %%
2**28
# Out:
# 268435456

# %%
#import task1 data 
task1_strong = pd.read_csv('strong_t1.csv')
# number of processors
np=array(task1_strong['nproc'])

#serial time
T1 = array(task1_strong['time'][0])

#parallel time
Tp = array(task1_strong['time'])

#speed up
s = T1/Tp

#efficiency plot
eff = s/np

#ideal curve
e = s/s

# %%
figure(2)
loglog(np,s,"-*",label='measurement')
loglog(np,np,label='ideal')
ylabel("speed up")
grid()
xlabel("number of processes")
title("speed up plot strong scaling for $N=2^{28}$ task1")
legend()
figure(3)
semilogx(np,eff,"-*",label='measurement')
semilogx(np,e,label='ideal')
title("Efficiency plot strong scaling for $N=2^{28}$ task1")
ylabel("efficiency")
xlabel("number of processes")
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# # weak scaling

# %%
#import task1 data 
task1_weak = pd.read_csv('weak_sc1.csv')
# number of processors
np=array(task1_weak['nproc'])

#serial time
Tw1 = array(task1_weak['time'][0])

#parallel time
Twp = array(task1_weak['time'])

#speed 
sw = Tw1/Twp

sw1 = np*sw

#efficiency plot
effw = sw1/np

e = sw/sw
#task1_weak
figure(5)
semilogx(np,effw,"-*",label='measurement')
semilogx(np,e,label='ideal')
title("Efficiency plot weak scaling task1")
ylabel("efficiency")
xlabel("number of processes")
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# # Task2. 2)

# %% [markdown]
# # with memory allocation

# %%
#import task2 data
task_1 = pd.read_csv('task1.csv')
task_2 = pd.read_csv('task2.csv')
task_3 = pd.read_csv('task3.csv')

#time
time_1 = array(task_1['time'])
time_2 = array(task_2['time'])
time_3 = array(task_3['time'])

N = array(task_2['N'])
task_3
# Out:
#              N         I     Error      time
# 0         1000  0.503511  0.003511  0.265354
# 1        10000  0.495528  0.004472  0.242565
# 2       100000  0.499741  0.000259  0.247534
# 3      1000000  0.499534  0.000466  0.248085
# 4     10000000  0.499930  0.000070  0.247726
# 5    100000000  0.500034  0.000034  0.284514
# 6   1000000000  0.500016  0.000016  0.597360
# 7  10000000000  0.499990  0.000010  0.738947

# %%
figure(9)
loglog(N,time_1,'-*',label='MPI')
loglog(N,time_2,'-*',label='Cuda_task2')
#loglog(N,time3,'--o',label='Cuda_task3')
title('Time against N')
xlabel('N')
ylabel('Time')
legend()
grid()
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
figure(10)
loglog(N,time_1,'-*',label='MPI')
loglog(N,time_2,'-*',label='Cuda_task2')
loglog(N,time_3,'--o',label='Cuda_task3')
title('Time against N')
xlabel('N')
ylabel('Time')
legend()
grid()
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# # without memory allocation

# %%
#import task2 data
task2 = pd.read_csv('task_2.csv')
task3 = pd.read_csv('task_3.csv')

#time
time2 = array(task2['time'])
time3 = array(task3['time'])

N = array(task2['N'])

# %%
figure(6)
loglog(N,time,'-*',label='MPI')
loglog(N,time2,'-*',label='Cuda_task2')
loglog(N,time3,'--o',label='Cuda_task3')
title('Time against N')
xlabel('N')
ylabel('Time')
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
figure(7)
loglog(N,time2,'-o',label='Cuda_task2')
loglog(N,time3,'--*',label='Cuda_task3')
title('Time against N')
xlabel('N')
ylabel('Time')
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
figure(8)
loglog(N,time,'-*',label='MPI')
loglog(N,time2,'-*',label='Cuda_task2')
#loglog(N,time3,'--o',label='Cuda_task3')
title('Time against N')
xlabel('N')
ylabel('Time')
legend()
grid()
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

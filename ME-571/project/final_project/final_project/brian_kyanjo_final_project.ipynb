# %% [markdown]
# # Final Project
# ## Name: Brian KYANJO
# ### Class: ME 571
# #### Date: April, 21st 2021

# %%
# %matplotlib notebook
# %pylab
import pandas as pd
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Task1. 2)

# %%
#import task1 data
task1 = pd.read_csv('task_1.csv')

time = array(task1['time'])
N = array(task1['N'])
task1
# Out:
#              N  nproc  uexact       umc       time
# 0         1000     64     0.5  0.530708   0.054137
# 1        10000     64     0.5  0.501987   0.065319
# 2       100000     64     0.5  0.510623   0.061090
# 3      1000000     64     0.5  0.496435   0.061191
# 4     10000000     64     0.5  0.500678   0.077533
# 5    100000000     64     0.5  0.500446   0.211332
# 6   1000000000     64     0.5  0.499932   1.580029
# 7  10000000000     64     0.5  0.500019  15.730502

# %%
ep = 1e-5
Np = 100/(ep**2)
n = zeros(len(N)); n[0] = Np

# %%
time[7]
# Out:
# 15.730502

# %%
figure(1)
#plot(N7,t7,"o")
loglog(N,time,'-*')
#loglog(error,time,'-*')
vlines(N[7],0,time[7],'r','--')
hlines(time[7],0,N[7],'r','--')

title('Time against N')
xlabel('N')
#xlim(0e3,1e13)
ylabel('Time')
grid()
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# # strong scaling

# %%
2**28
# Out:
# 268435456

# %%
#import task1 data 
task1_strong = pd.read_csv('strong_t1.csv')
# number of processors
np=array(task1_strong['nproc'])

#serial time
T1 = array(task1_strong['time'][0])

#parallel time
Tp = array(task1_strong['time'])

#speed up
s = T1/Tp

#efficiency plot
eff = s/np

#ideal curve
e = s/s

# %%
figure(2)
loglog(np,s,"-*",label='measurement')
loglog(np,np,label='ideal')
ylabel("speed up")
grid()
xlabel("number of processes")
title("speed up plot strong scaling for $N=2^{28}$ task1")
legend()
figure(3)
semilogx(np,eff,"-*",label='measurement')
semilogx(np,e,label='ideal')
title("Efficiency plot strong scaling for $N=2^{28}$ task1")
ylabel("efficiency")
xlabel("number of processes")
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# # weak scaling

# %%
#import task1 data 
task1_weak = pd.read_csv('weak_sc1.csv')
# number of processors
np=array(task1_weak['nproc'])

#serial time
Tw1 = array(task1_weak['time'][0])

#parallel time
Twp = array(task1_weak['time'])

#speed 
sw = Tw1/Twp

sw1 = np*sw

#efficiency plot
effw = sw1/np

e = sw/sw
#task1_weak
figure(5)
semilogx(np,effw,"-*",label='measurement')
semilogx(np,e,label='ideal')
title("Efficiency plot weak scaling task1")
ylabel("efficiency")
xlabel("number of processes")
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# # Task2. 2)

# %% [markdown]
# # with memory allocation

# %%
#import task2 data
task_1 = pd.read_csv('task1.csv')
task_2 = pd.read_csv('task2.csv')
task_3 = pd.read_csv('task3.csv')

#time
time_1 = array(task_1['time'])
time_2 = array(task_2['time_s'])
time_3 = array(task_3['time_s'])

N = array(task_2['N'])

# %%
figure(9)
loglog(N,time_1,'-*',label='MPI')
#loglog(N,,'-*',label='MPI')
loglog(N,time_2,'-*',label='Cuda_task2')
loglog(N,time_3,'--o',label='Cuda_task3')
title('Time against N')
xlabel('N')
ylabel('Time')
legend()
grid()
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
figure(10)
loglog(N,time_1,'-*',label='MPI')
loglog(N,time_2,'-*',label='Cuda_task2')
loglog(N,time_3,'--o',label='Cuda_task3')
title('Time against N')
xlabel('N')
ylabel('Time')
legend()
grid()
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# # without memory allocation

# %%
#import task2 data
task2 = pd.read_csv('task2.csv')
task3 = pd.read_csv('task3.csv')

#time
time2 = array(task2['time_c'])
time3 = array(task3['time_c'])

N = array(task2['N'])

# %%
figure(6)
loglog(N,time,'-*',label='MPI')
loglog(N,time2,'-*',label='Cuda_task2')
loglog(N,time3,'--o',label='Cuda_task3')
title('Time against N')
xlabel('N')
ylabel('Time')
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
figure(7)
loglog(N,time2,'-o',label='Cuda_task2')
loglog(N,time3,'--*',label='Cuda_task3')
title('Time against N')
xlabel('N')
ylabel('Time')
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
figure(8)
loglog(N,time,'-*',label='MPI')
loglog(N,time2,'-*',label='Cuda_task2')
#loglog(N,time3,'--o',label='Cuda_task3')
title('Time against N')
xlabel('N')
ylabel('Time')
legend()
grid()
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

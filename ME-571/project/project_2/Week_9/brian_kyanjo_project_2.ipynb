# %% [markdown]
# # Project_2
# ## Name: Brian KYANJO
# ### Class: ME 571
# #### Date: March, 15th 2021

# %%
# %matplotlib notebook
# %pylab
import pandas as pd
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Task 2
# ## Perform strong scaling

# %%
#import task2 data
task2_strong = pd.read_csv('task2_strong.csv')
T1 = array(task2_strong['gtime'][0])

# number of processors
np=array(task2_strong['nproc'])

#serial time
T1 = array(task2_strong['gtime'][0])

#parallel time
Tp = array(task2_strong['gtime'])

#speed up
s = T1/Tp

#efficiency plot
eff = s/np

#ideal curve
e = s/s

# %%
#ploting
figure(1)
loglog(np,s,"-*",label='measurement')
loglog(np,np,label='ideal')
ylabel("speed up")
grid()
xlabel("number of processes")
title("speed up plot strong scaling for $N=840$ task2")
legend()
figure(2)
semilogx(np,eff,"-*",label='measurement')
semilogx(np,e,label='ideal')
title("Efficiency plot strong scaling for $N=840$ task2")
ylabel("efficiency")
xlabel("number of processes")
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Task 3
# ## Perform strong scaling

# %%
#import task3 data
task3_strong = pd.read_csv('task3_strong.csv')

# number of processors
np=array(task3_strong['nproc'])

#serial time
T13 = array(task3_strong['gtime'][0])

#parallel time
Tp3 = array(task3_strong['gtime'])

#speed up
s3 = T13/Tp3

#efficiency plot
eff3 = s3/np

#ideal curve
e3 = s3/s3

# %%
#ploting
legend()
figure(3)
semilogx(np,eff,"-o",label='2D-decomposition')
semilogx(np,eff3,"--*",label='1D-decomposition')
semilogx(np,e3,label='ideal')
title("Efficiency plot strong scaling for $N=840$")
ylabel("efficiency")
xlabel("number of processes")
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Mastery
# ## Perform strong scaling

# %%
#import mastery data
mastery_strong = pd.read_csv('mastery_strong.csv')

# number of processors
np=array(mastery_strong['nproc'])

#serial time
T1m = array(mastery_strong['gtime'][0])

#parallel time
Tpm = array(mastery_strong['gtime'])

#speed up
sm = T1m/Tpm

#efficiency plot
effm = sm/np

#ideal curve
em = sm/sm

# %%
#ploting
legend()
figure(4)
semilogx(np,eff,"-*",label='2D-decomposition')
semilogx(np,eff3,"--*",label='1D-decomposition')
semilogx(np,effm,"--*",label='non-blocking')
semilogx(np,e3,label='ideal')
title("Efficiency plot strong scaling for $N=840$")
ylabel("efficiency")
xlabel("number of processes")
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Mastery_4

# %%
#import mastery data
mastery_strong = pd.read_csv('mastery_4.csv')

# number of processors
Nloc=array(mastery_strong['Nloc'])

#import tcomputation
tcomp = array(mastery_strong['tcomp'])

#import tcommunication
tcomm = array(mastery_strong['tcomm'])

#x-axis
N_loc = Nloc**2

# %%
#ploting
figure(5)
loglog(N_loc,tcomp,'-*',label='tcomp')
loglog(N_loc,tcomm,'-o',label='tcomm')
xlabel('$Nloc^{2}$');ylabel('tcomp and tcomm')
title('Time against $Nloc^{2}$')
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
N_loc
# Out:
# array([705600, 176400,  78400,  44100,  28224,  19600,  14400])

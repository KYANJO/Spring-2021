# %% [markdown]
# # Project_3
# ## Name: Brian KYANJO
# ### Class: ME 571
# #### Date: April, 7th 2021

# %%
# %matplotlib notebook
# %pylab
import pandas as pd
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Task 3
# ## Time plot

# %%
#import task2 data
task2 = pd.read_csv('task2.csv')
task3 = pd.read_csv('task3.csv')

# timming results
Tgpu2 = array(task2['iElaps_g'])
Tgpu3 = array(task3['iElaps_g'])

# number of threads
nb3=array(task3['nb'])
nb = array(task2['nb'])
nb2 = nb*nb
task3
# Out:
#      nb  iElaps_g   iElaps_h
# 0  1024  1.581834  58.061782
# 1   256  0.447988  58.035330
# 2    64  0.416222  58.613019
# 3    16  0.440542  57.958028
# 4     1  3.357724  59.091103

# %%
task2
# Out:
#    nb  iElaps_g
# 0  32  0.056697
# 1  16  0.059271
# 2   8  0.071918
# 3   4  0.152371
# 4   1  1.554026

# %%
#ploting
figure(1)
loglog(nb2,Tgpu2,"-*",label='Task2_gpu')
loglog(nb3,Tgpu3,"-o",label='Task3_gpu')
xlabel("number of threads")
grid()
ylabel("timings")
title("Time against number of threads for $N = 2^{11}$")
legend()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# %matplotlib notebook
# %pylab
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # No.2

# %%
#number of processors
np = array([1,2,4,8])

#time taken to complete intialisation 
tinit = array([8.250000e+00,4.710000e+00,1.920000e+00,1.140000e+00])
#time taken to complete computation 
tcomp = array([1.900000e+00,8.800000e-01,2.800000e-01,1.200000e-01])

# %%
#Plotting
figure(1)
loglog(np,tinit,'-*',label="initialisation_time")
loglog(np,tcomp,'-^',label="computation_time")
title("A graph of time vs number of processes")
xlabel("Number of processes")
ylabel("Time")
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Its observed that the simulation takes small time for computation than the initialiasation. Also from the results i observed that the last ranks actually use more time than the first ranks, however, still the computation time is lower than the intialsation  time for each run.

# %% [markdown]
# # No.4

# %%
#number of processors
np = array([1,2,4,8])

#time taken to complete intialisation 
#tinit = array([8.250000e+00,4.710000e+00,1.920000e+00,1.140000e+00])
#time taken to complete computation 
tcomp = array([2.900000e-01,1.600000e-01,8.000000e-02,4.000000e-02])

# %%
#Plotting
figure(2)
#loglog(np,tinit,'-*',label="initialisation_time")
loglog(np,tcomp,'-*',label="computation_time")
title("A graph of time vs number of processes")
xlabel("Number of processes")
ylabel("Time")
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# The cuvre is almost a straight line, this implies that Computational time is propotional to the number of processes. Its also observed that the computational time decreases as the number of processors increase

# %% [markdown]
# # hmwk3

# %%
tmen = array([0.129438,0.088389,0.075476,0.062593])
twomen = array([0.129892,0.088704,0.075186,0.062705])

# %%
#Plotting
figure(3)
loglog(np,tmen,'-*',label="tmen")
loglog(np,twomen,'-*',label="twomen")
title("A graph of time vs number of processes")
xlabel("Number of processes")
ylabel("Time")
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # mastery

# %%
tcompm = array([0.090601,0.053755,0.023166,0.012304])
tcomm = array([0.038875,0.044464,0.051548,0.050231])

# %%
#Plotting
figure(4)
loglog(np,tcompm,'-*',label="tcomputation")
loglog(np,tcomm,'-*',label="tcomunication")
title("A graph of time vs number of processes (men)")
xlabel("Number of processes")
ylabel("Time")
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tcompw = array([0.090676,0.047384,0.024172,0.012408])
tcomw= array([0.039118,0.043490,0.051929,0.049978])

# %%
#Plotting
figure(5)
loglog(np,tcompw,'-*',label="tcomputation")
loglog(np,tcomw,'-*',label="tcomunication")
title("A graph of time vs number of processes (women)")
xlabel("Number of processes")
ylabel("Time")
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Hmwk
# ### Class: ME 571
# #### Date: Febraury, 18th 2021

# %%
# %matplotlib notebook
# %pylab
import pandas as pd
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
task2_strong = pd.read_csv('strong.csv')
task2_strong
#np=array(task2_strong['N'])
#np
T1 = array(task2_strong[' gtime'][0])
T1
# Out:
# array(0.01669488)

# %% [markdown]
# # Task 2

# %%
#strong scaling

#import task1 data 
task2_strong = pd.read_csv('strong.csv')
# number of processors
np=array(task2_strong['nproc'])

#serial time
T1 = array(task2_strong[' gtime'][0])

#parallel time
Tp = array(task2_strong[' gtime'])

#speed up
s = T1/Tp

#efficiency plot
eff = s/np

#ideal curve
e = s/s

# %%
figure(1)
loglog(np,s,"-*",label='measurement')
loglog(np,np,label='ideal')
ylabel("speed up")
grid()
xlabel("number of processes")
title("speed up plot strong scaling for $N=2^{10}$ task1")
legend()
figure(2)
semilogx(np,eff,"-*",label='measurement')
semilogx(np,e,label='ideal')
title("Efficiency plot strong scaling for $N=2^{10}$ task1")
ylabel("efficiency")
xlabel("number of processes")
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
 #import task1 data
task2_weak = pd.read_csv('weak.csv') # number of processors np=array(task1_weak['nproc'])
#serial time
Tw2 = array(task2_weak[' gtime'][0]) #parallel time
Twp = array(task2_weak[' gtime']) #speed up
sw = Tw2/Twp
sw2 = np*Tw2/Twp
#efficiency plot
effw = sw2/np 
e = sw/sw

# %%
figure(3) 
loglog(np,sw2,"-*",label='measurement') 
loglog(np,np,label='ideal')
ylabel("speed up")
xlabel("number of processes")
legend()
grid()
title("speed up plot weak scaling task1") 
figure(4) 
semilogx(np,effw,"-*",label='measurement') 
semilogx(np,e,label='ideal') 
title("Efficiency plot weak scaling task1") 
ylabel("efficiency")
xlabel("number of processes")
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Task 3

# %%
#strong scaling

#import task1 data 
task2_strong = pd.read_csv('strong3.csv')
# number of processors
np=array(task2_strong['nproc'])

#serial time
T1 = array(task2_strong[' gtime'][0])

#parallel time
Tp = array(task2_strong[' gtime'])

#speed up
s = T1/Tp

#efficiency plot
eff = s/np

#ideal curve
e = s/s

# %%
figure(5)
loglog(np,s,"-*",label='measurement')
loglog(np,np,label='ideal')
ylabel("speed up")
grid()
xlabel("number of processes")
title("speed up plot strong scaling for $N=2^{10}$ task1")
legend()
figure(6)
semilogx(np,eff,"-*",label='measurement')
semilogx(np,e,label='ideal')
title("Efficiency plot strong scaling for $N=2^{10}$ task1")
ylabel("efficiency")
xlabel("number of processes")
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
 #import task1 data
task2_weak = pd.read_csv('weak3.csv') # number of processors np=array(task1_weak['nproc'])
#serial time
Tw2 = array(task2_weak[' gtime'][0]) #parallel time
Twp = array(task2_weak[' gtime']) #speed up
sw = Tw2/Twp
sw2 = np*Tw2/Twp
#efficiency plot
effw = sw2/np 
e = sw/sw

# %%
figure(7) 
loglog(np,sw2,"-*",label='measurement') 
loglog(np,np,label='ideal')
ylabel("speed up")
xlabel("number of processes")
legend()
grid()
title("speed up plot weak scaling task1") 
figure(8) 
semilogx(np,effw,"-*",label='measurement') 
semilogx(np,e,label='ideal') 
title("Efficiency plot weak scaling task1") 
ylabel("efficiency")
xlabel("number of processes")
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

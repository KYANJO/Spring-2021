# %% [markdown]
# ## Hmwk
# ### Class: ME 571
# #### Date: March, 5th 2021

# %%
# %matplotlib notebook
# %pylab
import pandas as pd
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib
# /Users/mathadmin/anaconda3/lib/python3.8/site-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['np', 'e']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
task2_strong = pd.read_csv('strong.csv')
task2_strong
#np=array(task2_strong['N'])
#np
T1 = array(task2_strong[' gtime'][0])
T1
# Out:
# array(0.01669488)

# %%
task2_strong
# Out:
#    nproc     N   u_error     gtime
# 0      1  1024  1.414222  0.016695
# 1      2  1024  0.006505  0.009712
# 2      4  1024  0.006505  0.006752
# 3      8  1024  0.006505  0.004942
# 4     16  1024  0.006505  0.004077
# 5     32  1024  0.006505  0.049514
# 6     64  1024  0.006505  0.043871

# %% [markdown]
# # Task 2

# %%
#strong scaling

#import task1 data 
task2_strong = pd.read_csv('strong.csv')
# number of processors
np=array(task2_strong['nproc'])

#serial time
T1 = array(task2_strong[' gtime'][0])

#parallel time
Tp = array(task2_strong[' gtime'])

#speed up
s = T1/Tp

#efficiency plot
eff = s/np

#ideal curve
e = s/s

# %%
figure(1)
loglog(np,s,"-*",label='measurement')
loglog(np,np,label='ideal')
ylabel("speed up")
grid()
xlabel("number of processes")
title("speed up plot strong scaling for $N=2^{10}$ task2")
legend()
figure(2)
loglog(np,eff,"-*",label='measurement')
loglog(np,e,label='ideal')
title("Efficiency plot strong scaling for $N=2^{10}$ task2")
ylabel("efficiency")
xlabel("number of processes")
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
 #import task1 data
task2_weak = pd.read_csv('weak.csv') # number of processors np=array(task1_weak['nproc'])
#serial time
Tw2 = array(task2_weak[' gtime'][0]) #parallel time
Twp = array(task2_weak[' gtime']) #speed up
sw = Tw2/Twp
sw2 = np*Tw2/Twp
#efficiency plot
effw = sw2/np 
e = sw/sw

# %%
figure(3) 
loglog(np,sw2,"-*",label='measurement') 
loglog(np,np,label='ideal')
ylabel("speed up")
xlabel("number of processes")
legend()
grid()
title("speed up plot weak scaling task2") 
figure(4) 
loglog(np,effw,"-*",label='measurement') 
loglog(np,e,label='ideal') 
title("Efficiency plot weak scaling task2") 
ylabel("efficiency")
xlabel("number of processes")
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Task 3

# %%
#strong scaling

#import task1 data 
task2_strong = pd.read_csv('strong3.csv')
# number of processors
np=array(task2_strong['nproc'])

#serial time
T1 = array(task2_strong[' gtime'][0])

#parallel time
Tp = array(task2_strong[' gtime'])

#speed up
s = T1/Tp

#efficiency plot
eff = s/np

#ideal curve
e = s/s

# %%
figure(5)
loglog(np,s,"-*",label='measurement')
loglog(np,np,label='ideal')
ylabel("speed up")
grid()
xlabel("number of processes")
title("speed up plot strong scaling for $N=2^{10}$ task3")
legend()
figure(6)
loglog(np,eff,"-*",label='measurement')
loglog(np,e,label='ideal')
title("Efficiency plot strong scaling for $N=2^{10}$ task3")
ylabel("efficiency")
xlabel("number of processes")
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
 #import task1 data
task2_weak = pd.read_csv('weak3.csv') # number of processors np=array(task1_weak['nproc'])
#serial time
Tw2 = array(task2_weak[' gtime'][0]) #parallel time
Twp = array(task2_weak[' gtime']) #speed up

sw = Tw2/Twp
sw2 = np*sw
#efficiency plot
effw = sw2/np 
e = sw/sw

# %%
eff = []
for i in range(len(np)):
    ef = Tw2/Twp[i]
    eff.append(ef)
effw = array(eff)

# %%
figure(7) 
loglog(np,sw2,"-*",label='measurement') 
loglog(np,np,label='ideal')
ylabel("speed up")
xlabel("number of processes")
legend()
grid()
title("speed up plot weak scaling task3") 
figure(8) 
loglog(np,effw,"-*",label='measurement') 
loglog(np,e,label='ideal') 
title("Efficiency plot weak scaling task3") 
ylabel("efficiency")
xlabel("number of processes")
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
pip install clawpack
# Out:
# Requirement already satisfied: clawpack in /Users/mathadmin/Project/clawpack (5.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib notebook
# %pylab
import pandas as pd
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Task 3

# %%
#import task3 data
task3_1 = pd.read_csv('results3_1.csv')
task3_2 = pd.read_csv('results3_2.csv')
task3_mpi = pd.read_csv('result3_mpi.csv')
task3_se = pd.read_csv('result3_se.csv')

T1 = array(task3_1['time'])
T2 = array(task3_2['time'])
Tmpi = array(task3_mpi['time'])
Tse = array(task3_se['time'])

# problem size
N=array(task3_1['N'])

# %%
#ploting
loglog(N,T1,'-*',label='task1_cuda')
loglog(N,T2,'-*',label='task2_cuda')
loglog(N,Tmpi,'-*',label='mpi')
loglog(N,Tse,'-*',label='serial')
title("Time plot")
ylabel("time")
xlabel("N")
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# # Task 3
# ## Perform strong scaling

# %%
#import task3 data
task3_strong = pd.read_csv('task3_strong.csv')

# number of processors
np=array(task3_strong['nproc'])

#serial time
T13 = array(task3_strong['gtime'][0])

#parallel time
Tp3 = array(task3_strong['gtime'])

#speed up
s3 = T13/Tp3

#efficiency plot
eff3 = s3/np

#ideal curve
e3 = s3/s3

# %%
#ploting
legend()
figure(3)
semilogx(np,eff,"-o",label='2D-decomposition')
semilogx(np,eff3,"--*",label='1D-decomposition')
semilogx(np,e3,label='ideal')
title("Efficiency plot strong scaling for $N=840$")
ylabel("efficiency")
xlabel("number of processes")
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Mastery
# ## Perform strong scaling

# %%
#import mastery data
mastery_strong = pd.read_csv('mastery_strong.csv')

# number of processors
np=array(mastery_strong['nproc'])

#serial time
T1m = array(mastery_strong['gtime'][0])

#parallel time
Tpm = array(mastery_strong['gtime'])

#speed up
sm = T1m/Tpm

#efficiency plot
effm = sm/np

#ideal curve
em = sm/sm

# %%
#ploting
legend()
figure(4)
semilogx(np,eff,"-*",label='2D-decomposition')
semilogx(np,eff3,"--*",label='1D-decomposition')
semilogx(np,effm,"--*",label='non-blocking')
semilogx(np,e3,label='ideal')
title("Efficiency plot strong scaling for $N=840$")
ylabel("efficiency")
xlabel("number of processes")
grid()
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Mastery_4

# %%
#import mastery data
mastery_strong = pd.read_csv('mastery_4.csv')

# number of processors
Nloc=array(mastery_strong['Nloc'])

#import tcomputation
tcomp = array(mastery_strong['tcomp'])

#import tcommunication
tcomm = array(mastery_strong['tcomm'])

#x-axis
N_loc = Nloc**2

# %%
#ploting
figure(5)
loglog(N_loc,tcomp,'-*',label='tcomp')
loglog(N_loc,tcomm,'-o',label='tcomm')
xlabel('$Nloc^{2}$');ylabel('tcomp and tcomm')
title('Time against $Nloc^{2}$')
legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
N_loc
# Out:
# array([705600, 176400,  78400,  44100,  28224,  19600,  14400])
